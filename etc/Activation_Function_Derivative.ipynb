# %% [markdown]
# # Activation Function 미분함수 구현

# %%
import numpy as np

# %% [markdown]
# ## tanh

# %%
'''
    Args:
        x: matrix
        return: original / derivative
'''
def tanh(x):
    t = (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
    dt = 1 - t ** 2
    return t, dt

# %%
z = np.arange(-4, 4, 0.01)
t, dt = tanh(z)
print(t)
print('================================================================')
print(dt)
# Out:
# [-9.99329300e-01 -9.99315755e-01 -9.99301937e-01 -9.99287841e-01
#  -9.99273459e-01 -9.99258788e-01 -9.99243820e-01 -9.99228550e-01
#  -9.99212972e-01 -9.99197079e-01 -9.99180866e-01 -9.99164325e-01
#  -9.99147450e-01 -9.99130235e-01 -9.99112673e-01 -9.99094756e-01
#  -9.99076477e-01 -9.99057829e-01 -9.99038805e-01 -9.99019397e-01
#  -9.98999598e-01 -9.98979399e-01 -9.98958792e-01 -9.98937769e-01
#  -9.98916322e-01 -9.98894443e-01 -9.98872122e-01 -9.98849350e-01
#  -9.98826119e-01 -9.98802419e-01 -9.98778241e-01 -9.98753575e-01
#  -9.98728412e-01 -9.98702741e-01 -9.98676552e-01 -9.98649835e-01
#  -9.98622578e-01 -9.98594772e-01 -9.98566405e-01 -9.98537465e-01
#  -9.98507942e-01 -9.98477824e-01 -9.98447098e-01 -9.98415752e-01
#  -9.98383774e-01 -9.98351151e-01 -9.98317870e-01 -9.98283918e-01
#  -9.98249281e-01 -9.98213945e-01 -9.98177898e-01 -9.98141123e-01
#  -9.98103607e-01 -9.98065334e-01 -9.98026290e-01 -9.97986458e-01
# ...

# %% [markdown]
# ## sigmoid

# %%
'''
    Args:
        x: matrix
        return: original / derivative
'''
def sigmoid(x):
    s = 1 / (1 + np.exp(-x))
    ds = s * (1 - s)
    return s, ds

# %%
s, ds = sigmoid(z)
print(s)
print('================================================================')
print(ds)
# Out:
# [0.01798621 0.01816369 0.01834289 0.01852382 0.01870651 0.01889096
#  0.0190772  0.01926523 0.01945508 0.01964677 0.01984031 0.02003571
#  0.020233   0.02043219 0.0206333  0.02083634 0.02104135 0.02124832
#  0.02145729 0.02166827 0.02188127 0.02209632 0.02231344 0.02253264
#  0.02275394 0.02297737 0.02320294 0.02343067 0.02366058 0.02389269
#  0.02412702 0.02436359 0.02460243 0.02484354 0.02508696 0.0253327
#  0.02558079 0.02583124 0.02608408 0.02633932 0.02659699 0.02685712
#  0.02711972 0.02738481 0.02765242 0.02792257 0.02819529 0.02847059
#  0.0287485  0.02902904 0.02931223 0.0295981  0.02988668 0.03017798
#  0.03047203 0.03076886 0.03106848 0.03137093 0.03167623 0.0319844
#  0.03229546 0.03260946 0.03292639 0.03324631 0.03356922 0.03389516
#  0.03422416 0.03455623 0.03489141 0.03522972 0.03557119 0.03591585
#  0.03626372 0.03661483 0.03696921 0.03732689 0.03768789 0.03805225
#  0.03841999 0.03879113 0.03916572 0.03954378 0.03992533 0.04031042
# ...
